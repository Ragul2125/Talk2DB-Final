# %%
import snowflake.connector

conn = snowflake.connector.connect(
    user='naveen',
    password='Naveen@04102005',
    account='kbvpier-li30198',
    warehouse='COMPUTE_WH',
    database='MEC',
    schema='SALES',
    role='ACCOUNTADMIN'
)

cursor = conn.cursor()
cursor.execute("SELECT CURRENT_TIMESTAMP()")
print("✅ Connected at:", cursor.fetchone()[0])
cursor.close()
conn.close()
# Out:
# INFO:snowflake.connector.connection:Snowflake Connector for Python Version: 3.13.2, Python Version: 3.10.11, Platform: Windows-10-10.0.26100-SP0
# INFO:snowflake.connector.connection:Connecting to GLOBAL Snowflake domain
# INFO:snowflake.connector.connection:This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1432, in SnowflakeConnection._authenticate(self, auth_instance)
#    1431 try:
# -> 1432     auth.authenticate(
#    1433         auth_instance=auth_instance,
#    1434         account=self.account,
#    1435         user=self.user,
#    1436         database=self.database,
#    1437         schema=self.schema,
#    1438         warehouse=self.warehouse,
#    1439         role=self.role,
#    1440         passcode=self._passcode,
#    1441         passcode_in_password=self._passcode_in_password,
#    1442         mfa_callback=self._mfa_callback,
#    1443         password_callback=self._password_callback,
#    1444         session_parameters=self._session_parameters,
#    1445     )
#    1446 except OperationalError as e:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\auth\_auth.py:265, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     264 try:
# --> 265     ret = self._rest._post_request(
#     266         url,
#     267         headers,
#     268         json.dumps(body),
#     269         socket_timeout=auth_instance._socket_timeout,
#     270     )
#     271 except ForbiddenError as err:
#     272     # HTTP 403
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:749, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     747     pprint(ret)
# --> 749 ret = self.fetch(
#     750     "post",
#     751     full_url,
#     752     headers,
#     753     data=body,
#     754     timeout=timeout,
#     755     token=token,
#     756     no_retry=no_retry,
#     757     _include_retry_params=_include_retry_params,
#     758     socket_timeout=socket_timeout,
#     759 )
#     760 logger.debug(
#     761     "ret[code] = {code}, after post request".format(
#     762         code=(ret.get("code", "N/A"))
#     763     )
#     764 )
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:864, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     863 while True:
# --> 864     ret = self._request_exec_wrapper(
#     865         session, method, full_url, headers, data, retry_ctx, **kwargs
#     866     )
#     867     if ret is not None:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:992, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     989 if (
#     990     raise_raw_http_failure and isinstance(e, requests.exceptions.HTTPError)
#     991 ) or not no_retry:
# --> 992     raise e
#     993 logger.debug("Ignored error", exc_info=True)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:914, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     913 try:
# --> 914     return_object = self._request_exec(
#     915         session=session,
#     916         method=method,
#     917         full_url=full_url,
#     918         headers=headers,
#     919         data=data,
#     920         token=token,
#     921         raise_raw_http_failure=raise_raw_http_failure,
#     922         **kwargs,
#     923     )
#     924     if return_object is not None:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:1191, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1190 except Exception as err:
# -> 1191     raise err
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:1081, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1078 # socket timeout is constant. You should be able to receive
#    1079 # the response within the time. If not, ConnectReadTimeout or
#    1080 # ReadTimeout is raised.
# -> 1081 raw_ret = session.request(
#    1082     method=method,
#    1083     url=full_url,
#    1084     headers=headers,
#    1085     data=input_data,
#    1086     timeout=socket_timeout,
#    1087     verify=True,
#    1088     stream=is_raw_binary,
#    1089     auth=SnowflakeAuth(token),
#    1090 )
#    1091 download_end_time = get_time_millis()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\ssl_wrap_socket.py:93, in ssl_wrap_socket_with_ocsp(*args, **kwargs)
#      92     if not v:
# ---> 93         raise OperationalError(
#      94             msg=(
#      95                 "The certificate is revoked or "
#      96                 "could not be validated: hostname={}".format(server_hostname)
#      97             ),
#      98             errno=ER_OCSP_RESPONSE_CERT_STATUS_REVOKED,
#      99         )
#     100 else:
#
# OperationalError: 254007: 254007: The certificate is revoked or could not be validated: hostname=kbvpier-li30198.snowflakecomputing.com
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 3
#       1 import snowflake.connector
# ----> 3 conn = snowflake.connector.connect(
#       4     user='naveen',
#       5     password='Naveen@04102005',
#       6     account='kbvpier-li30198',
#       7     warehouse='COMPUTE_WH',
#       8     database='MEC',
#       9     schema='SALES',
#      10     role='ACCOUNTADMIN'
#      11 )
#      13 cursor = conn.cursor()
#      14 cursor.execute("SELECT CURRENT_TIMESTAMP()")
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\__init__.py:55, in Connect(**kwargs)
#      53 @wraps(SnowflakeConnection.__init__)
#      54 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 55     return SnowflakeConnection(**kwargs)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:467, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     465     kwargs = _get_default_connection_params()
#     466 self.__set_error_attributes()
# --> 467 self.connect(**kwargs)
#     468 self._telemetry = TelemetryClient(self._rest)
#     469 self.expired = False
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:786, in SnowflakeConnection.connect(self, **kwargs)
#     784             raise Exception(str(exceptions_dict))
#     785 else:
# --> 786     self.__open_connection()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1116, in SnowflakeConnection.__open_connection(self)
#    1108 else:
#    1109     # okta URL, e.g., https://<account>.okta.com/
#    1110     self.auth_class = AuthByOkta(
#    1111         application=self.application,
#    1112         timeout=self.login_timeout,
#    1113         backoff_generator=self._backoff_generator,
#    1114     )
# -> 1116 self.authenticate_with_retry(self.auth_class)
#    1118 self._password = None  # ensure password won't persist
#    1119 self.auth_class.reset_secrets()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1404, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1401 def authenticate_with_retry(self, auth_instance) -> None:
#    1402     # make some changes if needed before real __authenticate
#    1403     try:
# -> 1404         self._authenticate(auth_instance)
#    1405     except ReauthenticationRequest as ex:
#    1406         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1407         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1478, in SnowflakeConnection._authenticate(self, auth_instance)
#    1476     if _CONNECTIVITY_ERR_MSG in e.msg:
#    1477         auth_op.msg += f"\n{_CONNECTIVITY_ERR_MSG}"
# -> 1478     raise auth_op from e
#    1479 logger.debug("Continuing authenticator specific timeout handling")
#    1480 continue
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1453, in SnowflakeConnection._authenticate(self, auth_instance)
#    1451 while True:
#    1452     try:
# -> 1453         auth_instance.handle_timeout(
#    1454             authenticator=self._authenticator,
#    1455             service_name=self.service_name,
#    1456             account=self.account,
#    1457             user=self.user,
#    1458             password=self._password,
#    1459         )
#    1460         auth.authenticate(
#    1461             auth_instance=auth_instance,
#    1462             account=self.account,
#    (...)
#    1472             session_parameters=self._session_parameters,
#    1473         )
#    1474     except OperationalError as auth_op:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\auth\by_plugin.py:213, in AuthByPlugin.handle_timeout(***failed resolving arguments***)
#     207 if not self._retry_ctx.should_retry:
#     208     error = OperationalError(
#     209         msg=f"Could not connect to Snowflake backend after {self._retry_ctx.current_retry_count + 1} attempt(s)."
#     210         "Aborting",
#     211         errno=ER_FAILED_TO_CONNECT_TO_DB,
#     212     )
# --> 213     raise error
#     214 else:
#     215     logger.debug(
#     216         f"Hit connection timeout, attempt number {self._retry_ctx.current_retry_count + 1}."
#     217         " Will retry in a bit..."
#     218     )
#
# OperationalError: 250001: 250001: Could not connect to Snowflake backend after 2 attempt(s).Aborting

# %%
# !pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in d:\talk2db(working)\talk2db\.venv\lib\site-packages (3.13.2)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (1.17.1)
# Requirement already satisfied: cryptography>=3.1.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (44.0.3)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=22.0.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (24.3.0)
# Requirement already satisfied: pyjwt<3.0.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2.10.1)
# Requirement already satisfied: pytz in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2025.2)
# Requirement already satisfied: requests<3.0.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: packaging in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2025.4.26)
# Requirement already satisfied: typing_extensions<5,>=4.3 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (4.13.2)
# Requirement already satisfied: filelock<4,>=3.5 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (3.18.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (4.3.8)
# Requirement already satisfied: tomlkit in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (0.13.2)
# Requirement already satisfied: pycparser in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from requests<3.0.0->snowflake-connector-python) (2.4.0)

# %%
import snowflake.connector

conn = snowflake.connector.connect(
    user='naveen',
    password='Naveen@04102005',
    account='kbvpier-li30198',
    warehouse='COMPUTE_WH',
    database='MEC',
    schema='SALES',
    role='ACCOUNTADMIN'
)

cursor = conn.cursor()
cursor.execute("SELECT CURRENT_TIMESTAMP()")
print("✅ Connected at:", cursor.fetchone()[0])
cursor.close()
conn.close()
# Out:
# INFO:snowflake.connector.connection:Snowflake Connector for Python Version: 3.13.2, Python Version: 3.10.11, Platform: Windows-10-10.0.26100-SP0
# INFO:snowflake.connector.connection:Connecting to GLOBAL Snowflake domain
# INFO:snowflake.connector.connection:This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1432, in SnowflakeConnection._authenticate(self, auth_instance)
#    1431 try:
# -> 1432     auth.authenticate(
#    1433         auth_instance=auth_instance,
#    1434         account=self.account,
#    1435         user=self.user,
#    1436         database=self.database,
#    1437         schema=self.schema,
#    1438         warehouse=self.warehouse,
#    1439         role=self.role,
#    1440         passcode=self._passcode,
#    1441         passcode_in_password=self._passcode_in_password,
#    1442         mfa_callback=self._mfa_callback,
#    1443         password_callback=self._password_callback,
#    1444         session_parameters=self._session_parameters,
#    1445     )
#    1446 except OperationalError as e:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\auth\_auth.py:265, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     264 try:
# --> 265     ret = self._rest._post_request(
#     266         url,
#     267         headers,
#     268         json.dumps(body),
#     269         socket_timeout=auth_instance._socket_timeout,
#     270     )
#     271 except ForbiddenError as err:
#     272     # HTTP 403
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:749, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     747     pprint(ret)
# --> 749 ret = self.fetch(
#     750     "post",
#     751     full_url,
#     752     headers,
#     753     data=body,
#     754     timeout=timeout,
#     755     token=token,
#     756     no_retry=no_retry,
#     757     _include_retry_params=_include_retry_params,
#     758     socket_timeout=socket_timeout,
#     759 )
#     760 logger.debug(
#     761     "ret[code] = {code}, after post request".format(
#     762         code=(ret.get("code", "N/A"))
#     763     )
#     764 )
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:864, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     863 while True:
# --> 864     ret = self._request_exec_wrapper(
#     865         session, method, full_url, headers, data, retry_ctx, **kwargs
#     866     )
#     867     if ret is not None:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:992, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     989 if (
#     990     raise_raw_http_failure and isinstance(e, requests.exceptions.HTTPError)
#     991 ) or not no_retry:
# --> 992     raise e
#     993 logger.debug("Ignored error", exc_info=True)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:914, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     913 try:
# --> 914     return_object = self._request_exec(
#     915         session=session,
#     916         method=method,
#     917         full_url=full_url,
#     918         headers=headers,
#     919         data=data,
#     920         token=token,
#     921         raise_raw_http_failure=raise_raw_http_failure,
#     922         **kwargs,
#     923     )
#     924     if return_object is not None:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:1191, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1190 except Exception as err:
# -> 1191     raise err
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:1081, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1078 # socket timeout is constant. You should be able to receive
#    1079 # the response within the time. If not, ConnectReadTimeout or
#    1080 # ReadTimeout is raised.
# -> 1081 raw_ret = session.request(
#    1082     method=method,
#    1083     url=full_url,
#    1084     headers=headers,
#    1085     data=input_data,
#    1086     timeout=socket_timeout,
#    1087     verify=True,
#    1088     stream=is_raw_binary,
#    1089     auth=SnowflakeAuth(token),
#    1090 )
#    1091 download_end_time = get_time_millis()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\ssl_wrap_socket.py:93, in ssl_wrap_socket_with_ocsp(*args, **kwargs)
#      92     if not v:
# ---> 93         raise OperationalError(
#      94             msg=(
#      95                 "The certificate is revoked or "
#      96                 "could not be validated: hostname={}".format(server_hostname)
#      97             ),
#      98             errno=ER_OCSP_RESPONSE_CERT_STATUS_REVOKED,
#      99         )
#     100 else:
#
# OperationalError: 254007: 254007: The certificate is revoked or could not be validated: hostname=kbvpier-li30198.snowflakecomputing.com
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 3
#       1 import snowflake.connector
# ----> 3 conn = snowflake.connector.connect(
#       4     user='naveen',
#       5     password='Naveen@04102005',
#       6     account='kbvpier-li30198',
#       7     warehouse='COMPUTE_WH',
#       8     database='MEC',
#       9     schema='SALES',
#      10     role='ACCOUNTADMIN'
#      11 )
#      13 cursor = conn.cursor()
#      14 cursor.execute("SELECT CURRENT_TIMESTAMP()")
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\__init__.py:55, in Connect(**kwargs)
#      53 @wraps(SnowflakeConnection.__init__)
#      54 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 55     return SnowflakeConnection(**kwargs)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:467, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     465     kwargs = _get_default_connection_params()
#     466 self.__set_error_attributes()
# --> 467 self.connect(**kwargs)
#     468 self._telemetry = TelemetryClient(self._rest)
#     469 self.expired = False
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:786, in SnowflakeConnection.connect(self, **kwargs)
#     784             raise Exception(str(exceptions_dict))
#     785 else:
# --> 786     self.__open_connection()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1116, in SnowflakeConnection.__open_connection(self)
#    1108 else:
#    1109     # okta URL, e.g., https://<account>.okta.com/
#    1110     self.auth_class = AuthByOkta(
#    1111         application=self.application,
#    1112         timeout=self.login_timeout,
#    1113         backoff_generator=self._backoff_generator,
#    1114     )
# -> 1116 self.authenticate_with_retry(self.auth_class)
#    1118 self._password = None  # ensure password won't persist
#    1119 self.auth_class.reset_secrets()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1404, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1401 def authenticate_with_retry(self, auth_instance) -> None:
#    1402     # make some changes if needed before real __authenticate
#    1403     try:
# -> 1404         self._authenticate(auth_instance)
#    1405     except ReauthenticationRequest as ex:
#    1406         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1407         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1478, in SnowflakeConnection._authenticate(self, auth_instance)
#    1476     if _CONNECTIVITY_ERR_MSG in e.msg:
#    1477         auth_op.msg += f"\n{_CONNECTIVITY_ERR_MSG}"
# -> 1478     raise auth_op from e
#    1479 logger.debug("Continuing authenticator specific timeout handling")
#    1480 continue
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1453, in SnowflakeConnection._authenticate(self, auth_instance)
#    1451 while True:
#    1452     try:
# -> 1453         auth_instance.handle_timeout(
#    1454             authenticator=self._authenticator,
#    1455             service_name=self.service_name,
#    1456             account=self.account,
#    1457             user=self.user,
#    1458             password=self._password,
#    1459         )
#    1460         auth.authenticate(
#    1461             auth_instance=auth_instance,
#    1462             account=self.account,
#    (...)
#    1472             session_parameters=self._session_parameters,
#    1473         )
#    1474     except OperationalError as auth_op:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\auth\by_plugin.py:213, in AuthByPlugin.handle_timeout(***failed resolving arguments***)
#     207 if not self._retry_ctx.should_retry:
#     208     error = OperationalError(
#     209         msg=f"Could not connect to Snowflake backend after {self._retry_ctx.current_retry_count + 1} attempt(s)."
#     210         "Aborting",
#     211         errno=ER_FAILED_TO_CONNECT_TO_DB,
#     212     )
# --> 213     raise error
#     214 else:
#     215     logger.debug(
#     216         f"Hit connection timeout, attempt number {self._retry_ctx.current_retry_count + 1}."
#     217         " Will retry in a bit..."
#     218     )
#
# OperationalError: 250001: 250001: Could not connect to Snowflake backend after 2 attempt(s).Aborting

# %%
import snowflake.connector

conn = snowflake.connector.connect(
    user='naveen',
    password='Naveen@04102005',
    account='kbvpier-li30198',
    warehouse='COMPUTE_WH',
    database='MEC',
    schema='SALES',
    role='ACCOUNTADMIN'
)

cursor = conn.cursor()
cursor.execute("SHOW TABLES;")
print("✅ Connected at:", cursor.fetchone()[1])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1345, in SnowflakeConnection._authenticate(self, auth_instance)
#    1344 try:
# -> 1345     auth.authenticate(
#    1346         auth_instance=auth_instance,
#    1347         account=self.account,
#    1348         user=self.user,
#    1349         database=self.database,
#    1350         schema=self.schema,
#    1351         warehouse=self.warehouse,
#    1352         role=self.role,
#    1353         passcode=self._passcode,
#    1354         passcode_in_password=self._passcode_in_password,
#    1355         mfa_callback=self._mfa_callback,
#    1356         password_callback=self._password_callback,
#    1357         session_parameters=self._session_parameters,
#    1358     )
#    1359 except OperationalError as e:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\auth\_auth.py:250, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     249 try:
# --> 250     ret = self._rest._post_request(
#     251         url,
#     252         headers,
#     253         json.dumps(body),
#     254         socket_timeout=auth_instance._socket_timeout,
#     255     )
#     256 except ForbiddenError as err:
#     257     # HTTP 403
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:734, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     732     pprint(ret)
# --> 734 ret = self.fetch(
#     735     "post",
#     736     full_url,
#     737     headers,
#     738     data=body,
#     739     timeout=timeout,
#     740     token=token,
#     741     no_retry=no_retry,
#     742     _include_retry_params=_include_retry_params,
#     743     socket_timeout=socket_timeout,
#     744 )
#     745 logger.debug(
#     746     "ret[code] = {code}, after post request".format(
#     747         code=(ret.get("code", "N/A"))
#     748     )
#     749 )
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:843, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     842 while True:
# --> 843     ret = self._request_exec_wrapper(
#     844         session, method, full_url, headers, data, retry_ctx, **kwargs
#     845     )
#     846     if ret is not None:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:979, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     978 if not no_retry:
# --> 979     raise e
#     980 logger.debug("Ignored error", exc_info=True)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:884, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     883 try:
# --> 884     return_object = self._request_exec(
#     885         session=session,
#     886         method=method,
#     887         full_url=full_url,
#     888         headers=headers,
#     889         data=data,
#     890         token=token,
#     891         **kwargs,
#     892     )
#     893     if return_object is not None:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:1193, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication)
#    1184 TelemetryService.get_instance().log_http_request_error(
#    1185     "HttpException%s" % str(err),
#    1186     full_url,
#    (...)
#    1191     stack_trace=traceback.format_exc(),
#    1192 )
# -> 1193 raise err
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\network.py:1078, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication)
#    1075 # socket timeout is constant. You should be able to receive
#    1076 # the response within the time. If not, ConnectReadTimeout or
#    1077 # ReadTimeout is raised.
# -> 1078 raw_ret = session.request(
#    1079     method=method,
#    1080     url=full_url,
#    1081     headers=headers,
#    1082     data=input_data,
#    1083     timeout=socket_timeout,
#    1084     verify=True,
#    1085     stream=is_raw_binary,
#    1086     auth=SnowflakeAuth(token),
#    1087 )
#    1088 download_end_time = get_time_millis()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\vendored\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\ssl_wrap_socket.py:92, in ssl_wrap_socket_with_ocsp(*args, **kwargs)
#      91     if not v:
# ---> 92         raise OperationalError(
#      93             msg=(
#      94                 "The certificate is revoked or "
#      95                 "could not be validated: hostname={}".format(server_hostname)
#      96             ),
#      97             errno=ER_OCSP_RESPONSE_CERT_STATUS_REVOKED,
#      98         )
#      99 else:
#
# OperationalError: 254007: The certificate is revoked or could not be validated: hostname=kbvpier-li30198.snowflakecomputing.com
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 3
#       1 import snowflake.connector
# ----> 3 conn = snowflake.connector.connect(
#       4     user='naveen',
#       5     password='Naveen@04102005',
#       6     account='kbvpier-li30198',
#       7     warehouse='COMPUTE_WH',
#       8     database='MEC',
#       9     schema='SALES',
#      10     role='ACCOUNTADMIN'
#      11 )
#      13 cursor = conn.cursor()
#      14 cursor.execute("SHOW TABLES;")
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\__init__.py:54, in Connect(**kwargs)
#      52 @wraps(SnowflakeConnection.__init__)
#      53 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 54     return SnowflakeConnection(**kwargs)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:429, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     427     kwargs = _get_default_connection_params()
#     428 self.__set_error_attributes()
# --> 429 self.connect(**kwargs)
#     430 self._telemetry = TelemetryClient(self._rest)
#     431 self.expired = False
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:719, in SnowflakeConnection.connect(self, **kwargs)
#     717             raise Exception(str(exceptions_dict))
#     718 else:
# --> 719     self.__open_connection()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1045, in SnowflakeConnection.__open_connection(self)
#    1037 else:
#    1038     # okta URL, e.g., https://<account>.okta.com/
#    1039     self.auth_class = AuthByOkta(
#    1040         application=self.application,
#    1041         timeout=self._login_timeout,
#    1042         backoff_generator=self._backoff_generator,
#    1043     )
# -> 1045 self.authenticate_with_retry(self.auth_class)
#    1047 self._password = None  # ensure password won't persist
#    1048 self.auth_class.reset_secrets()
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1317, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1314 def authenticate_with_retry(self, auth_instance) -> None:
#    1315     # make some changes if needed before real __authenticate
#    1316     try:
# -> 1317         self._authenticate(auth_instance)
#    1318     except ReauthenticationRequest as ex:
#    1319         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1320         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1389, in SnowflakeConnection._authenticate(self, auth_instance)
#    1387 except OperationalError as auth_op:
#    1388     if auth_op.errno == ER_FAILED_TO_CONNECT_TO_DB:
# -> 1389         raise auth_op from e
#    1390     logger.debug("Continuing authenticator specific timeout handling")
#    1391     continue
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\connection.py:1366, in SnowflakeConnection._authenticate(self, auth_instance)
#    1364 while True:
#    1365     try:
# -> 1366         auth_instance.handle_timeout(
#    1367             authenticator=self._authenticator,
#    1368             service_name=self.service_name,
#    1369             account=self.account,
#    1370             user=self.user,
#    1371             password=self._password,
#    1372         )
#    1373         auth.authenticate(
#    1374             auth_instance=auth_instance,
#    1375             account=self.account,
#    (...)
#    1385             session_parameters=self._session_parameters,
#    1386         )
#    1387     except OperationalError as auth_op:
#
# File d:\talk2db(working)\talk2db\.venv\lib\site-packages\snowflake\connector\auth\by_plugin.py:212, in AuthByPlugin.handle_timeout(***failed resolving arguments***)
#     206 if not self._retry_ctx.should_retry:
#     207     error = OperationalError(
#     208         msg=f"Could not connect to Snowflake backend after {self._retry_ctx.current_retry_count + 1} attempt(s)."
#     209         "Aborting",
#     210         errno=ER_FAILED_TO_CONNECT_TO_DB,
#     211     )
# --> 212     raise error
#     213 else:
#     214     logger.debug(
#     215         f"Hit connection timeout, attempt number {self._retry_ctx.current_retry_count + 1}."
#     216         " Will retry in a bit..."
#     217     )
#
# OperationalError: 250001: Could not connect to Snowflake backend after 2 attempt(s).Aborting

# %%
import os
os.environ["NO_PROXY"] = "snowflakecomputing.com"


import snowflake.connector
conn = snowflake.connector.connect(
    user='naveen',
    password='Naveen@04102005',
    account='kbvpier-li30198',
    session_parameters={"CLIENT_SESSION_KEEP_ALIVE": True}
)
print("✅ Connected Successfully")
# Out:
# ✅ Connected Successfully

# %%
pip install --upgrade snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in d:\talk2db(working)\talk2db\.venv\lib\site-packages (3.7.0)
# Collecting snowflake-connector-python
#   Downloading snowflake_connector_python-3.15.0-cp310-cp310-win_amd64.whl.metadata (72 kB)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Collecting boto3>=1.24 (from snowflake-connector-python)
#   Downloading boto3-1.38.23-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore>=1.24 (from snowflake-connector-python)
#   Downloading botocore-1.38.23-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (1.17.1)
# Requirement already satisfied: cryptography>=3.1.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (41.0.7)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (23.3.0)
# Requirement already satisfied: pyjwt<3.0.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2.10.1)
# Requirement already satisfied: pytz in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2025.2)
# Requirement already satisfied: requests<3.0.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: packaging in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2025.4.26)
# Requirement already satisfied: typing_extensions<5,>=4.3 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (4.13.2)
# Requirement already satisfied: filelock<4,>=3.5 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (3.18.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (3.11.0)
# Requirement already satisfied: tomlkit in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from snowflake-connector-python) (0.13.2)
# Requirement already satisfied: pycparser in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from requests<3.0.0->snowflake-connector-python) (2.4.0)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.24->snowflake-connector-python)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3>=1.24->snowflake-connector-python)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from botocore>=1.24->snowflake-connector-python) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\talk2db(working)\talk2db\.venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.24->snowflake-connector-python) (1.17.0)
# Downloading snowflake_connector_python-3.15.0-cp310-cp310-win_amd64.whl (948 kB)
#    ---------------------------------------- 0.0/948.4 kB ? eta -:--:--
#    ---------------------------------------- 948.4/948.4 kB 8.8 MB/s eta 0:00:00
# Downloading boto3-1.38.23-py3-none-any.whl (139 kB)
# Downloading botocore-1.38.23-py3-none-any.whl (13.6 MB)
#    ---------------------------------------- 0.0/13.6 MB ? eta -:--:--
#    --------- ------------------------------ 3.1/13.6 MB 16.8 MB/s eta 0:00:01
#    --------- ------------------------------ 3.1/13.6 MB 16.8 MB/s eta 0:00:01
#    ------------------- -------------------- 6.6/13.6 MB 10.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.0/13.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 12.8/13.6 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 13.6/13.6 MB 12.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
# Installing collected packages: jmespath, botocore, s3transfer, boto3, snowflake-connector-python
#
#    ---------------------------------------- 0/5 [jmespath]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    -------- ------------------------------- 1/5 [botocore]
#    ---------------- ----------------------- 2/5 [s3transfer]
#    ---------------- ----------------------- 2/5 [s3transfer]
#    ---------------- ----------------------- 2/5 [s3transfer]
#    ------------------------ --------------- 3/5 [boto3]
#    ------------------------ --------------- 3/5 [boto3]
#    ------------------------ --------------- 3/5 [boto3]
#    ------------------------ --------------- 3/5 [boto3]
#    ------------------------ --------------- 3/5 [boto3]
#   Attempting uninstall: snowflake-connector-python
#    ------------------------ --------------- 3/5 [boto3]
#     Found existing installation: snowflake-connector-python 3.7.0
#    ------------------------ --------------- 3/5 [boto3]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#     Uninstalling snowflake-connector-python-3.7.0:
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#       Successfully uninstalled snowflake-connector-python-3.7.0
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    -------------------------------- ------- 4/5 [snowflake-connector-python]
#    ---------------------------------------- 5/5 [snowflake-connector-python]
#
# Successfully installed boto3-1.38.23 botocore-1.38.23 jmespath-1.0.1 s3transfer-0.13.0 snowflake-connector-python-3.15.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'D:\talk2db(working)\talk2db\.venv\Lib\site-packages\snowflake\~onnector'.
#   You can safely remove it manually.

# %%
# Out:
# ✅ Connected to MongoDB!
